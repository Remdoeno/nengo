# %% [markdown]
# # NEF summary
#
# The Neural Engineering Framework (NEF)
# is one set of theoretical methods that are used in
# Nengo for constructing neural models.
# The NEF is based on [Eliasmith & Anderson's (2003) book](
# https://mitpress.mit.edu/books/neural-engineering) from MIT Press.
# This notebook introduces the three main principles
# discussed in that book and implemented in Nengo.

# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt

import nengo
from nengo.dists import Uniform
from nengo.processes import WhiteSignal
from nengo.utils.ensemble import tuning_curves
from nengo.utils.ipython import hide_input
from nengo.utils.matplotlib import rasterplot


def aligned(n_neurons, radius=0.9):
    intercepts = np.linspace(-radius, radius, n_neurons)
    encoders = np.tile([[1], [-1]], (n_neurons // 2, 1))
    intercepts *= encoders[:, 0]
    return intercepts, encoders


hide_input()
# Out:
#         <a id="1280069741" href="javascript:toggle_input_1280069741()"
#           >Show Input</a>
#
#         <script type="text/javascript">
#         var toggle_input_1280069741;
#         (function() {
#             if (typeof jQuery == 'undefined') {
#                 // no jQuery
#                 var link_1280069741 = document.getElementById("1280069741");
#                 var cell = link_1280069741;
#                 while (cell.className.split(' ')[0] != "cell"
#                        && cell.className.split(' ')[0] != "nboutput") {
#                     cell = cell.parentNode;
#                 }
#                 var input_1280069741;
#                 if (cell.className.split(' ')[0] == "cell") {
#                     for (var i = 0; i < cell.children.length; i++) {
#                         if (cell.children[i].className.split(' ')[0]
#                             == "input") {
#                             input_1280069741 = cell.children[i];
#                         }
#                     }
#                 } else {
#                     input_1280069741 = cell.previousElementSibling;
#                 }
#                 input_1280069741.style.display = "none"; // hide
#
#                 toggle_input_1280069741 = function() {
#                     if (input_1280069741.style.display == "none") {
#                         input_1280069741.style.display = ""; // show
#                         link_1280069741.innerHTML = "Hide Input";
#                     } else {
#                         input_1280069741.style.display = "none"; // hide
#                         link_1280069741.innerHTML = "Show Input";
#                     }
#                 }
#
#             } else {
#                 // jQuery
#                 var link_1280069741 = $("a[id='1280069741']");
#                 var cell_1280069741 = link_1280069741.parents("div.cell:first");
#                 if (cell_1280069741.length == 0) {
#                     cell_1280069741 = link_1280069741.parents(
#                         "div.nboutput:first");
#                 }
#                 var input_1280069741 = cell_1280069741.children("div.input");
#                 if (input_1280069741.length == 0) {
#                     input_1280069741 = cell_1280069741.prev("div.nbinput");
#                 }
#                 input_1280069741.hide();
#
#                 toggle_input_1280069741 = function() {
#                     if (input_1280069741.is(':hidden')) {
#                         input_1280069741.slideDown();
#                         link_1280069741[0].innerHTML = "Hide Input";
#                     } else {
#                         input_1280069741.slideUp();
#                         link_1280069741[0].innerHTML = "Show Input";
#                     }
#                 }
#             }
#         }());
#         </script>

# %% [markdown]
# ## Principle 1: Representation
#
# ### Encoding
#
# Neural populations represent time-varying signals
# through their spiking responses.
# A signal is a vector of real numbers of arbitrary length.
# This example is a 1D signal going from -1 to 1 in 1 second.

# %%
model = nengo.Network(label="NEF summary")
with model:
    input = nengo.Node(lambda t: t * 2 - 1)
    input_probe = nengo.Probe(input)

# %%
with nengo.Simulator(model) as sim:
    sim.run(1.0)

plt.figure()
plt.plot(sim.trange(), sim.data[input_probe], lw=2)
plt.title("Input signal")
plt.xlabel("Time (s)")
plt.xlim(0, 1);
hide_input()
# Out:
#         <a id="2130631145" href="javascript:toggle_input_2130631145()"
#           >Show Input</a>
#
#         <script type="text/javascript">
#         var toggle_input_2130631145;
#         (function() {
#             if (typeof jQuery == 'undefined') {
#                 // no jQuery
#                 var link_2130631145 = document.getElementById("2130631145");
#                 var cell = link_2130631145;
#                 while (cell.className.split(' ')[0] != "cell"
#                        && cell.className.split(' ')[0] != "nboutput") {
#                     cell = cell.parentNode;
#                 }
#                 var input_2130631145;
#                 if (cell.className.split(' ')[0] == "cell") {
#                     for (var i = 0; i < cell.children.length; i++) {
#                         if (cell.children[i].className.split(' ')[0]
#                             == "input") {
#                             input_2130631145 = cell.children[i];
#                         }
#                     }
#                 } else {
#                     input_2130631145 = cell.previousElementSibling;
#                 }
#                 input_2130631145.style.display = "none"; // hide
#
#                 toggle_input_2130631145 = function() {
#                     if (input_2130631145.style.display == "none") {
#                         input_2130631145.style.display = ""; // show
#                         link_2130631145.innerHTML = "Hide Input";
#                     } else {
#                         input_2130631145.style.display = "none"; // hide
#                         link_2130631145.innerHTML = "Show Input";
#                     }
#                 }
#
#             } else {
#                 // jQuery
#                 var link_2130631145 = $("a[id='2130631145']");
#                 var cell_2130631145 = link_2130631145.parents("div.cell:first");
#                 if (cell_2130631145.length == 0) {
#                     cell_2130631145 = link_2130631145.parents(
#                         "div.nboutput:first");
#                 }
#                 var input_2130631145 = cell_2130631145.children("div.input");
#                 if (input_2130631145.length == 0) {
#                     input_2130631145 = cell_2130631145.prev("div.nbinput");
#                 }
#                 input_2130631145.hide();
#
#                 toggle_input_2130631145 = function() {
#                     if (input_2130631145.is(':hidden')) {
#                         input_2130631145.slideDown();
#                         link_2130631145[0].innerHTML = "Hide Input";
#                     } else {
#                         input_2130631145.slideUp();
#                         link_2130631145[0].innerHTML = "Show Input";
#                     }
#                 }
#             }
#         }());
#         </script>

# %% [markdown]
# These signals drive neural populations
# based on each neuron's *tuning curve*
# (which is similar to the current-frequency curve,
# if you're familiar with that).
#
# The tuning curve describes how much
# a particular neuron will fire as a function of the input signal.

# %%
intercepts, encoders = aligned(8)  # Makes evenly spaced intercepts
with model:
    A = nengo.Ensemble(
        8,
        dimensions=1,
        intercepts=intercepts,
        max_rates=Uniform(80, 100),
        encoders=encoders)

# %%
with nengo.Simulator(model) as sim:
    eval_points, activities = tuning_curves(A, sim)

plt.figure()
plt.plot(eval_points, activities, lw=2)
plt.xlabel("Input signal")
plt.ylabel("Firing rate (Hz)");
hide_input()
# Out:
#         <a id="1806513075" href="javascript:toggle_input_1806513075()"
#           >Show Input</a>
#
#         <script type="text/javascript">
#         var toggle_input_1806513075;
#         (function() {
#             if (typeof jQuery == 'undefined') {
#                 // no jQuery
#                 var link_1806513075 = document.getElementById("1806513075");
#                 var cell = link_1806513075;
#                 while (cell.className.split(' ')[0] != "cell"
#                        && cell.className.split(' ')[0] != "nboutput") {
#                     cell = cell.parentNode;
#                 }
#                 var input_1806513075;
#                 if (cell.className.split(' ')[0] == "cell") {
#                     for (var i = 0; i < cell.children.length; i++) {
#                         if (cell.children[i].className.split(' ')[0]
#                             == "input") {
#                             input_1806513075 = cell.children[i];
#                         }
#                     }
#                 } else {
#                     input_1806513075 = cell.previousElementSibling;
#                 }
#                 input_1806513075.style.display = "none"; // hide
#
#                 toggle_input_1806513075 = function() {
#                     if (input_1806513075.style.display == "none") {
#                         input_1806513075.style.display = ""; // show
#                         link_1806513075.innerHTML = "Hide Input";
#                     } else {
#                         input_1806513075.style.display = "none"; // hide
#                         link_1806513075.innerHTML = "Show Input";
#                     }
#                 }
#
#             } else {
#                 // jQuery
#                 var link_1806513075 = $("a[id='1806513075']");
#                 var cell_1806513075 = link_1806513075.parents("div.cell:first");
#                 if (cell_1806513075.length == 0) {
#                     cell_1806513075 = link_1806513075.parents(
#                         "div.nboutput:first");
#                 }
#                 var input_1806513075 = cell_1806513075.children("div.input");
#                 if (input_1806513075.length == 0) {
#                     input_1806513075 = cell_1806513075.prev("div.nbinput");
#                 }
#                 input_1806513075.hide();
#
#                 toggle_input_1806513075 = function() {
#                     if (input_1806513075.is(':hidden')) {
#                         input_1806513075.slideDown();
#                         link_1806513075[0].innerHTML = "Hide Input";
#                     } else {
#                         input_1806513075.slideUp();
#                         link_1806513075[0].innerHTML = "Show Input";
#                     }
#                 }
#             }
#         }());
#         </script>

# %% [markdown]
# We can drive these neurons with our input signal
# and observe their spiking activity over time.

# %%
with model:
    nengo.Connection(input, A)
    A_spikes = nengo.Probe(A.neurons)

# %%
with nengo.Simulator(model) as sim:
    sim.run(1)

plt.figure()
ax = plt.subplot(1, 1, 1)
rasterplot(sim.trange(), sim.data[A_spikes], ax)
ax.set_xlim(0, 1)
ax.set_ylabel('Neuron')
ax.set_xlabel('Time (s)');
hide_input()
# Out:
#         <a id="1398369607" href="javascript:toggle_input_1398369607()"
#           >Show Input</a>
#
#         <script type="text/javascript">
#         var toggle_input_1398369607;
#         (function() {
#             if (typeof jQuery == 'undefined') {
#                 // no jQuery
#                 var link_1398369607 = document.getElementById("1398369607");
#                 var cell = link_1398369607;
#                 while (cell.className.split(' ')[0] != "cell"
#                        && cell.className.split(' ')[0] != "nboutput") {
#                     cell = cell.parentNode;
#                 }
#                 var input_1398369607;
#                 if (cell.className.split(' ')[0] == "cell") {
#                     for (var i = 0; i < cell.children.length; i++) {
#                         if (cell.children[i].className.split(' ')[0]
#                             == "input") {
#                             input_1398369607 = cell.children[i];
#                         }
#                     }
#                 } else {
#                     input_1398369607 = cell.previousElementSibling;
#                 }
#                 input_1398369607.style.display = "none"; // hide
#
#                 toggle_input_1398369607 = function() {
#                     if (input_1398369607.style.display == "none") {
#                         input_1398369607.style.display = ""; // show
#                         link_1398369607.innerHTML = "Hide Input";
#                     } else {
#                         input_1398369607.style.display = "none"; // hide
#                         link_1398369607.innerHTML = "Show Input";
#                     }
#                 }
#
#             } else {
#                 // jQuery
#                 var link_1398369607 = $("a[id='1398369607']");
#                 var cell_1398369607 = link_1398369607.parents("div.cell:first");
#                 if (cell_1398369607.length == 0) {
#                     cell_1398369607 = link_1398369607.parents(
#                         "div.nboutput:first");
#                 }
#                 var input_1398369607 = cell_1398369607.children("div.input");
#                 if (input_1398369607.length == 0) {
#                     input_1398369607 = cell_1398369607.prev("div.nbinput");
#                 }
#                 input_1398369607.hide();
#
#                 toggle_input_1398369607 = function() {
#                     if (input_1398369607.is(':hidden')) {
#                         input_1398369607.slideDown();
#                         link_1398369607[0].innerHTML = "Hide Input";
#                     } else {
#                         input_1398369607.slideUp();
#                         link_1398369607[0].innerHTML = "Show Input";
#                     }
#                 }
#             }
#         }());
#         </script>

# %% [markdown]
# ### Decoding
#
# We can estimate the input signal
# originally encoded by decoding the pattern of spikes.
# To do this, we first filter the spike train
# with a temporal filter that accounts for
# postsynaptic current (PSC) activity.

# %%
model = nengo.Network(label="NEF summary")
with model:
    input = nengo.Node(lambda t: t * 2 - 1)
    input_probe = nengo.Probe(input)
    intercepts, encoders = aligned(8)  # Makes evenly spaced intercepts
    A = nengo.Ensemble(8, dimensions=1,
                       intercepts=intercepts,
                       max_rates=Uniform(80, 100),
                       encoders=encoders)
    nengo.Connection(input, A)
    A_spikes = nengo.Probe(A.neurons, synapse=0.01)

# %%
with nengo.Simulator(model) as sim:
    sim.run(1)

scale = 180
plt.figure()
for i in range(A.n_neurons):
    plt.plot(sim.trange(), sim.data[A_spikes][:, i] - i * scale)
plt.xlim(0, 1)
plt.ylim(scale * (-A.n_neurons + 1), scale)
plt.ylabel("Neuron")
plt.yticks(
    np.arange(scale / 1.8, (-A.n_neurons + 1) * scale, -scale),
    np.arange(A.n_neurons))
hide_input()
# Out:
#         <a id="1268445363" href="javascript:toggle_input_1268445363()"
#           >Show Input</a>
#
#         <script type="text/javascript">
#         var toggle_input_1268445363;
#         (function() {
#             if (typeof jQuery == 'undefined') {
#                 // no jQuery
#                 var link_1268445363 = document.getElementById("1268445363");
#                 var cell = link_1268445363;
#                 while (cell.className.split(' ')[0] != "cell"
#                        && cell.className.split(' ')[0] != "nboutput") {
#                     cell = cell.parentNode;
#                 }
#                 var input_1268445363;
#                 if (cell.className.split(' ')[0] == "cell") {
#                     for (var i = 0; i < cell.children.length; i++) {
#                         if (cell.children[i].className.split(' ')[0]
#                             == "input") {
#                             input_1268445363 = cell.children[i];
#                         }
#                     }
#                 } else {
#                     input_1268445363 = cell.previousElementSibling;
#                 }
#                 input_1268445363.style.display = "none"; // hide
#
#                 toggle_input_1268445363 = function() {
#                     if (input_1268445363.style.display == "none") {
#                         input_1268445363.style.display = ""; // show
#                         link_1268445363.innerHTML = "Hide Input";
#                     } else {
#                         input_1268445363.style.display = "none"; // hide
#                         link_1268445363.innerHTML = "Show Input";
#                     }
#                 }
#
#             } else {
#                 // jQuery
#                 var link_1268445363 = $("a[id='1268445363']");
#                 var cell_1268445363 = link_1268445363.parents("div.cell:first");
#                 if (cell_1268445363.length == 0) {
#                     cell_1268445363 = link_1268445363.parents(
#                         "div.nboutput:first");
#                 }
#                 var input_1268445363 = cell_1268445363.children("div.input");
#                 if (input_1268445363.length == 0) {
#                     input_1268445363 = cell_1268445363.prev("div.nbinput");
#                 }
#                 input_1268445363.hide();
#
#                 toggle_input_1268445363 = function() {
#                     if (input_1268445363.is(':hidden')) {
#                         input_1268445363.slideDown();
#                         link_1268445363[0].innerHTML = "Hide Input";
#                     } else {
#                         input_1268445363.slideUp();
#                         link_1268445363[0].innerHTML = "Show Input";
#                     }
#                 }
#             }
#         }());
#         </script>

# %% [markdown]
# Then we mulitply those filtered spike trains
# with decoding weights and sum them together
# to give an estimate of the input based on the spikes.
#
# The decoding weights are determined
# by minimizing the squared difference
# between the decoded estimate and the actual input signal.

# %%
with model:
    A_probe = nengo.Probe(A, synapse=0.01)  # 10ms PSC filter

# %%
with nengo.Simulator(model) as sim:
    sim.run(1)

plt.figure()
plt.plot(sim.trange(), sim.data[input_probe], label="Input signal")
plt.plot(sim.trange(), sim.data[A_probe], label="Decoded estimate")
plt.legend(loc="best")
plt.xlim(0, 1)
hide_input()
# Out:
#         <a id="139640058" href="javascript:toggle_input_139640058()"
#           >Show Input</a>
#
#         <script type="text/javascript">
#         var toggle_input_139640058;
#         (function() {
#             if (typeof jQuery == 'undefined') {
#                 // no jQuery
#                 var link_139640058 = document.getElementById("139640058");
#                 var cell = link_139640058;
#                 while (cell.className.split(' ')[0] != "cell"
#                        && cell.className.split(' ')[0] != "nboutput") {
#                     cell = cell.parentNode;
#                 }
#                 var input_139640058;
#                 if (cell.className.split(' ')[0] == "cell") {
#                     for (var i = 0; i < cell.children.length; i++) {
#                         if (cell.children[i].className.split(' ')[0]
#                             == "input") {
#                             input_139640058 = cell.children[i];
#                         }
#                     }
#                 } else {
#                     input_139640058 = cell.previousElementSibling;
#                 }
#                 input_139640058.style.display = "none"; // hide
#
#                 toggle_input_139640058 = function() {
#                     if (input_139640058.style.display == "none") {
#                         input_139640058.style.display = ""; // show
#                         link_139640058.innerHTML = "Hide Input";
#                     } else {
#                         input_139640058.style.display = "none"; // hide
#                         link_139640058.innerHTML = "Show Input";
#                     }
#                 }
#
#             } else {
#                 // jQuery
#                 var link_139640058 = $("a[id='139640058']");
#                 var cell_139640058 = link_139640058.parents("div.cell:first");
#                 if (cell_139640058.length == 0) {
#                     cell_139640058 = link_139640058.parents(
#                         "div.nboutput:first");
#                 }
#                 var input_139640058 = cell_139640058.children("div.input");
#                 if (input_139640058.length == 0) {
#                     input_139640058 = cell_139640058.prev("div.nbinput");
#                 }
#                 input_139640058.hide();
#
#                 toggle_input_139640058 = function() {
#                     if (input_139640058.is(':hidden')) {
#                         input_139640058.slideDown();
#                         link_139640058[0].innerHTML = "Hide Input";
#                     } else {
#                         input_139640058.slideUp();
#                         link_139640058[0].innerHTML = "Show Input";
#                     }
#                 }
#             }
#         }());
#         </script>

# %% [markdown]
# The accuracy of the decoded estimate increases
# as the number of neurons increases.

# %%
model = nengo.Network(label="NEF summary")
with model:
    input = nengo.Node(lambda t: t * 2 - 1)
    input_probe = nengo.Probe(input)
    A = nengo.Ensemble(30, dimensions=1, max_rates=Uniform(80, 100))
    nengo.Connection(input, A)
    A_spikes = nengo.Probe(A.neurons)
    A_probe = nengo.Probe(A, synapse=0.01)

# %%
with nengo.Simulator(model) as sim:
    sim.run(1)

plt.figure(figsize=(15, 3.5))

plt.subplot(1, 3, 1)
eval_points, activities = tuning_curves(A, sim)
plt.plot(eval_points, activities, lw=2)
plt.xlabel("Input signal")
plt.ylabel("Firing rate (Hz)")

ax = plt.subplot(1, 3, 2)
rasterplot(sim.trange(), sim.data[A_spikes], ax)
plt.xlim(0, 1)
plt.xlabel("Time (s)")
plt.ylabel("Neuron")

plt.subplot(1, 3, 3)
plt.plot(sim.trange(), sim.data[input_probe], label="Input signal")
plt.plot(sim.trange(), sim.data[A_probe], label="Decoded esimate")
plt.legend(loc="best")
plt.xlabel("Time (s)")
plt.xlim(0, 1)
hide_input()
# Out:
#         <a id="95278264" href="javascript:toggle_input_95278264()"
#           >Show Input</a>
#
#         <script type="text/javascript">
#         var toggle_input_95278264;
#         (function() {
#             if (typeof jQuery == 'undefined') {
#                 // no jQuery
#                 var link_95278264 = document.getElementById("95278264");
#                 var cell = link_95278264;
#                 while (cell.className.split(' ')[0] != "cell"
#                        && cell.className.split(' ')[0] != "nboutput") {
#                     cell = cell.parentNode;
#                 }
#                 var input_95278264;
#                 if (cell.className.split(' ')[0] == "cell") {
#                     for (var i = 0; i < cell.children.length; i++) {
#                         if (cell.children[i].className.split(' ')[0]
#                             == "input") {
#                             input_95278264 = cell.children[i];
#                         }
#                     }
#                 } else {
#                     input_95278264 = cell.previousElementSibling;
#                 }
#                 input_95278264.style.display = "none"; // hide
#
#                 toggle_input_95278264 = function() {
#                     if (input_95278264.style.display == "none") {
#                         input_95278264.style.display = ""; // show
#                         link_95278264.innerHTML = "Hide Input";
#                     } else {
#                         input_95278264.style.display = "none"; // hide
#                         link_95278264.innerHTML = "Show Input";
#                     }
#                 }
#
#             } else {
#                 // jQuery
#                 var link_95278264 = $("a[id='95278264']");
#                 var cell_95278264 = link_95278264.parents("div.cell:first");
#                 if (cell_95278264.length == 0) {
#                     cell_95278264 = link_95278264.parents(
#                         "div.nboutput:first");
#                 }
#                 var input_95278264 = cell_95278264.children("div.input");
#                 if (input_95278264.length == 0) {
#                     input_95278264 = cell_95278264.prev("div.nbinput");
#                 }
#                 input_95278264.hide();
#
#                 toggle_input_95278264 = function() {
#                     if (input_95278264.is(':hidden')) {
#                         input_95278264.slideDown();
#                         link_95278264[0].innerHTML = "Hide Input";
#                     } else {
#                         input_95278264.slideUp();
#                         link_95278264[0].innerHTML = "Show Input";
#                     }
#                 }
#             }
#         }());
#         </script>

# %% [markdown]
# Any smooth signal can be encoded and decoded.

# %%
model = nengo.Network(label="NEF summary")
with model:
    input = nengo.Node(WhiteSignal(1, high=5), size_out=1)
    input_probe = nengo.Probe(input)
    A = nengo.Ensemble(30, dimensions=1, max_rates=Uniform(80, 100))
    nengo.Connection(input, A)
    A_spikes = nengo.Probe(A.neurons)
    A_probe = nengo.Probe(A, synapse=0.01)

# %%
with nengo.Simulator(model) as sim:
    sim.run(1)

plt.figure(figsize=(10, 3.5))
plt.subplot(1, 2, 1)
plt.plot(sim.trange(), sim.data[input_probe], label="Input signal")
plt.plot(sim.trange(), sim.data[A_probe], label="Decoded esimate")
plt.legend(loc="best")
plt.xlabel("Time (s)")
plt.xlim(0, 1)

ax = plt.subplot(1, 2, 2)
rasterplot(sim.trange(), sim.data[A_spikes], ax)
plt.xlim(0, 1)
plt.xlabel("Time (s)")
plt.ylabel("Neuron")
hide_input()
# Out:
#         <a id="1731537724" href="javascript:toggle_input_1731537724()"
#           >Show Input</a>
#
#         <script type="text/javascript">
#         var toggle_input_1731537724;
#         (function() {
#             if (typeof jQuery == 'undefined') {
#                 // no jQuery
#                 var link_1731537724 = document.getElementById("1731537724");
#                 var cell = link_1731537724;
#                 while (cell.className.split(' ')[0] != "cell"
#                        && cell.className.split(' ')[0] != "nboutput") {
#                     cell = cell.parentNode;
#                 }
#                 var input_1731537724;
#                 if (cell.className.split(' ')[0] == "cell") {
#                     for (var i = 0; i < cell.children.length; i++) {
#                         if (cell.children[i].className.split(' ')[0]
#                             == "input") {
#                             input_1731537724 = cell.children[i];
#                         }
#                     }
#                 } else {
#                     input_1731537724 = cell.previousElementSibling;
#                 }
#                 input_1731537724.style.display = "none"; // hide
#
#                 toggle_input_1731537724 = function() {
#                     if (input_1731537724.style.display == "none") {
#                         input_1731537724.style.display = ""; // show
#                         link_1731537724.innerHTML = "Hide Input";
#                     } else {
#                         input_1731537724.style.display = "none"; // hide
#                         link_1731537724.innerHTML = "Show Input";
#                     }
#                 }
#
#             } else {
#                 // jQuery
#                 var link_1731537724 = $("a[id='1731537724']");
#                 var cell_1731537724 = link_1731537724.parents("div.cell:first");
#                 if (cell_1731537724.length == 0) {
#                     cell_1731537724 = link_1731537724.parents(
#                         "div.nboutput:first");
#                 }
#                 var input_1731537724 = cell_1731537724.children("div.input");
#                 if (input_1731537724.length == 0) {
#                     input_1731537724 = cell_1731537724.prev("div.nbinput");
#                 }
#                 input_1731537724.hide();
#
#                 toggle_input_1731537724 = function() {
#                     if (input_1731537724.is(':hidden')) {
#                         input_1731537724.slideDown();
#                         link_1731537724[0].innerHTML = "Hide Input";
#                     } else {
#                         input_1731537724.slideUp();
#                         link_1731537724[0].innerHTML = "Show Input";
#                     }
#                 }
#             }
#         }());
#         </script>

# %% [markdown]
# ## Principle 2: Transformation
#
# Encoding and decoding allow us to encode signals over time,
# and decode transformations of those signals.
#
# In fact, we can decode arbitrary transformations of the input signal,
# not just the signal itself (as in the previous example).
#
# Let's decode the square of our white noise input.

# %%
model = nengo.Network(label="NEF summary")
with model:
    input = nengo.Node(WhiteSignal(1, high=5), size_out=1)
    input_probe = nengo.Probe(input, )
    A = nengo.Ensemble(30, dimensions=1, max_rates=Uniform(80, 100))
    Asquare = nengo.Node(size_in=1)
    nengo.Connection(input, A)
    nengo.Connection(A, Asquare, function=np.square)
    A_spikes = nengo.Probe(A.neurons)
    Asquare_probe = nengo.Probe(Asquare, synapse=0.01)

# %%
with nengo.Simulator(model) as sim:
    sim.run(1)

plt.figure(figsize=(10, 3.5))
plt.subplot(1, 2, 1)
plt.plot(
    sim.trange(),
    sim.data[input_probe],
    label="Input signal")
plt.plot(
    sim.trange(),
    sim.data[Asquare_probe],
    label="Decoded esimate")
plt.plot(
    sim.trange(),
    np.square(sim.data[input_probe]),
    label="Input signal squared")
plt.legend(loc="best", fontsize='medium')
plt.xlabel("Time (s)")
plt.xlim(0, 1)

ax = plt.subplot(1, 2, 2)
rasterplot(sim.trange(), sim.data[A_spikes])
plt.xlim(0, 1)
plt.xlabel("Time (s)")
plt.ylabel("Neuron")
hide_input()
# Out:
#         <a id="335654344" href="javascript:toggle_input_335654344()"
#           >Show Input</a>
#
#         <script type="text/javascript">
#         var toggle_input_335654344;
#         (function() {
#             if (typeof jQuery == 'undefined') {
#                 // no jQuery
#                 var link_335654344 = document.getElementById("335654344");
#                 var cell = link_335654344;
#                 while (cell.className.split(' ')[0] != "cell"
#                        && cell.className.split(' ')[0] != "nboutput") {
#                     cell = cell.parentNode;
#                 }
#                 var input_335654344;
#                 if (cell.className.split(' ')[0] == "cell") {
#                     for (var i = 0; i < cell.children.length; i++) {
#                         if (cell.children[i].className.split(' ')[0]
#                             == "input") {
#                             input_335654344 = cell.children[i];
#                         }
#                     }
#                 } else {
#                     input_335654344 = cell.previousElementSibling;
#                 }
#                 input_335654344.style.display = "none"; // hide
#
#                 toggle_input_335654344 = function() {
#                     if (input_335654344.style.display == "none") {
#                         input_335654344.style.display = ""; // show
#                         link_335654344.innerHTML = "Hide Input";
#                     } else {
#                         input_335654344.style.display = "none"; // hide
#                         link_335654344.innerHTML = "Show Input";
#                     }
#                 }
#
#             } else {
#                 // jQuery
#                 var link_335654344 = $("a[id='335654344']");
#                 var cell_335654344 = link_335654344.parents("div.cell:first");
#                 if (cell_335654344.length == 0) {
#                     cell_335654344 = link_335654344.parents(
#                         "div.nboutput:first");
#                 }
#                 var input_335654344 = cell_335654344.children("div.input");
#                 if (input_335654344.length == 0) {
#                     input_335654344 = cell_335654344.prev("div.nbinput");
#                 }
#                 input_335654344.hide();
#
#                 toggle_input_335654344 = function() {
#                     if (input_335654344.is(':hidden')) {
#                         input_335654344.slideDown();
#                         link_335654344[0].innerHTML = "Hide Input";
#                     } else {
#                         input_335654344.slideUp();
#                         link_335654344[0].innerHTML = "Show Input";
#                     }
#                 }
#             }
#         }());
#         </script>

# %% [markdown]
# Notice that the spike trains are exactly the same.
# The only difference is how we're interpreting those spikes.
# We told Nengo to compute a new set of decoders
# that estimate the function $x^2$.
#
# In general, the transformation principle
# determines how we can decode spike trains
# to compute linear and nonlinear transformations of signals
# encoded in a population of neurons.
# We can then project those transformed signals
# into another population, and repeat the process.
# Essentially, this provides a means of
# computing the neural connection weights
# to compute an arbitrary function between populations.
#
# Suppose we are representing a sine wave.

# %%
model = nengo.Network(label="NEF summary")
with model:
    input = nengo.Node(lambda t: np.sin(np.pi * t))
    A = nengo.Ensemble(30, dimensions=1, max_rates=Uniform(80, 100))
    nengo.Connection(input, A)
    A_spikes = nengo.Probe(A.neurons)
    A_probe = nengo.Probe(A, synapse=0.01)

# %%
with nengo.Simulator(model) as sim:
    sim.run(2)

plt.figure(figsize=(10, 3.5))
plt.subplot(1, 2, 1)
plt.plot(sim.trange(), sim.data[A_probe])
plt.title("A")
plt.xlabel("Time (s)")
plt.xlim(0, 2)

ax = plt.subplot(1, 2, 2)
rasterplot(sim.trange(), sim.data[A_spikes], ax)
plt.xlim(0, 2)
plt.title("A")
plt.xlabel("Time (s)")
plt.ylabel("Neuron")
hide_input()
# Out:
#         <a id="922673182" href="javascript:toggle_input_922673182()"
#           >Show Input</a>
#
#         <script type="text/javascript">
#         var toggle_input_922673182;
#         (function() {
#             if (typeof jQuery == 'undefined') {
#                 // no jQuery
#                 var link_922673182 = document.getElementById("922673182");
#                 var cell = link_922673182;
#                 while (cell.className.split(' ')[0] != "cell"
#                        && cell.className.split(' ')[0] != "nboutput") {
#                     cell = cell.parentNode;
#                 }
#                 var input_922673182;
#                 if (cell.className.split(' ')[0] == "cell") {
#                     for (var i = 0; i < cell.children.length; i++) {
#                         if (cell.children[i].className.split(' ')[0]
#                             == "input") {
#                             input_922673182 = cell.children[i];
#                         }
#                     }
#                 } else {
#                     input_922673182 = cell.previousElementSibling;
#                 }
#                 input_922673182.style.display = "none"; // hide
#
#                 toggle_input_922673182 = function() {
#                     if (input_922673182.style.display == "none") {
#                         input_922673182.style.display = ""; // show
#                         link_922673182.innerHTML = "Hide Input";
#                     } else {
#                         input_922673182.style.display = "none"; // hide
#                         link_922673182.innerHTML = "Show Input";
#                     }
#                 }
#
#             } else {
#                 // jQuery
#                 var link_922673182 = $("a[id='922673182']");
#                 var cell_922673182 = link_922673182.parents("div.cell:first");
#                 if (cell_922673182.length == 0) {
#                     cell_922673182 = link_922673182.parents(
#                         "div.nboutput:first");
#                 }
#                 var input_922673182 = cell_922673182.children("div.input");
#                 if (input_922673182.length == 0) {
#                     input_922673182 = cell_922673182.prev("div.nbinput");
#                 }
#                 input_922673182.hide();
#
#                 toggle_input_922673182 = function() {
#                     if (input_922673182.is(':hidden')) {
#                         input_922673182.slideDown();
#                         link_922673182[0].innerHTML = "Hide Input";
#                     } else {
#                         input_922673182.slideUp();
#                         link_922673182[0].innerHTML = "Show Input";
#                     }
#                 }
#             }
#         }());
#         </script>

# %% [markdown]
# Linear transformations of that signal
# involve solving for the usual decoders,
# and scaling those decoding weights.
# Let us flip this sine wave upside down
# as it is transmitted between two populations
# (i.e. population A and population -A).

# %%
with model:
    minusA = nengo.Ensemble(30, dimensions=1, max_rates=Uniform(80, 100))
    nengo.Connection(A, minusA, function=lambda x: -x)
    minusA_spikes = nengo.Probe(minusA.neurons)
    minusA_probe = nengo.Probe(minusA, synapse=0.01)

# %%
with nengo.Simulator(model) as sim:
    sim.run(2)

plt.figure(figsize=(10, 5))
plt.subplot(2, 2, 1)
plt.plot(sim.trange(), sim.data[A_probe])
plt.title("A")
plt.xticks(())
plt.xlim(0, 2)

plt.subplot(2, 2, 3)
plt.plot(sim.trange(), sim.data[minusA_probe])
plt.title("-A")
plt.xlabel("Time (s)")
plt.xlim(0, 2)

ax = plt.subplot(2, 2, 2)
rasterplot(sim.trange(), sim.data[A_spikes], ax)
plt.xlim(0, 2)
plt.title("A")
plt.xticks(())
plt.ylabel("Neuron")

ax = plt.subplot(2, 2, 4)
rasterplot(sim.trange(), sim.data[minusA_spikes], ax)
plt.xlim(0, 2)
plt.title("-A")
plt.xlabel("Time (s)")
plt.ylabel("Neuron")
hide_input()
# Out:
#         <a id="928237097" href="javascript:toggle_input_928237097()"
#           >Show Input</a>
#
#         <script type="text/javascript">
#         var toggle_input_928237097;
#         (function() {
#             if (typeof jQuery == 'undefined') {
#                 // no jQuery
#                 var link_928237097 = document.getElementById("928237097");
#                 var cell = link_928237097;
#                 while (cell.className.split(' ')[0] != "cell"
#                        && cell.className.split(' ')[0] != "nboutput") {
#                     cell = cell.parentNode;
#                 }
#                 var input_928237097;
#                 if (cell.className.split(' ')[0] == "cell") {
#                     for (var i = 0; i < cell.children.length; i++) {
#                         if (cell.children[i].className.split(' ')[0]
#                             == "input") {
#                             input_928237097 = cell.children[i];
#                         }
#                     }
#                 } else {
#                     input_928237097 = cell.previousElementSibling;
#                 }
#                 input_928237097.style.display = "none"; // hide
#
#                 toggle_input_928237097 = function() {
#                     if (input_928237097.style.display == "none") {
#                         input_928237097.style.display = ""; // show
#                         link_928237097.innerHTML = "Hide Input";
#                     } else {
#                         input_928237097.style.display = "none"; // hide
#                         link_928237097.innerHTML = "Show Input";
#                     }
#                 }
#
#             } else {
#                 // jQuery
#                 var link_928237097 = $("a[id='928237097']");
#                 var cell_928237097 = link_928237097.parents("div.cell:first");
#                 if (cell_928237097.length == 0) {
#                     cell_928237097 = link_928237097.parents(
#                         "div.nboutput:first");
#                 }
#                 var input_928237097 = cell_928237097.children("div.input");
#                 if (input_928237097.length == 0) {
#                     input_928237097 = cell_928237097.prev("div.nbinput");
#                 }
#                 input_928237097.hide();
#
#                 toggle_input_928237097 = function() {
#                     if (input_928237097.is(':hidden')) {
#                         input_928237097.slideDown();
#                         link_928237097[0].innerHTML = "Hide Input";
#                     } else {
#                         input_928237097.slideUp();
#                         link_928237097[0].innerHTML = "Show Input";
#                     }
#                 }
#             }
#         }());
#         </script>

# %% [markdown]
# Nonlinear transformations involve
# solving for a new set of decoding weights.
# Let us add a third population connected
# to the second one and use it to compute $(-A)^2$.

# %%
with model:
    A_squared = nengo.Ensemble(30, dimensions=1, max_rates=Uniform(80, 100))
    nengo.Connection(minusA, A_squared, function=lambda x: x ** 2)
    A_squared_spikes = nengo.Probe(A_squared.neurons)
    A_squared_probe = nengo.Probe(A_squared, synapse=0.02)

# %%
with nengo.Simulator(model) as sim:
    sim.run(2)

plt.figure(figsize=(10, 6.5))
plt.subplot(3, 2, 1)
plt.plot(sim.trange(), sim.data[A_probe])
plt.axhline(0, color='k')
plt.title("A")
plt.xticks(())
plt.xlim(0, 2)

plt.subplot(3, 2, 3)
plt.plot(sim.trange(), sim.data[minusA_probe])
plt.axhline(0, color='k')
plt.title("-A")
plt.xticks(())
plt.xlim(0, 2)

plt.subplot(3, 2, 5)
plt.plot(sim.trange(), sim.data[A_squared_probe])
plt.axhline(0, color='k')
plt.title("(-A)^2")
plt.xlabel("Time (s)")
plt.xlim(0, 2)

ax = plt.subplot(3, 2, 2)
rasterplot(sim.trange(), sim.data[A_spikes], ax)
plt.xlim(0, 2)
plt.title("A")
plt.xticks(())
plt.ylabel("Neuron")

ax = plt.subplot(3, 2, 4)
rasterplot(sim.trange(), sim.data[minusA_spikes], ax)
plt.xlim(0, 2)
plt.title("-A")
plt.xticks(())
plt.ylabel("Neuron")

ax = plt.subplot(3, 2, 6)
rasterplot(sim.trange(), sim.data[A_squared_spikes], ax)
plt.xlim(0, 2)
plt.title("(-A)^2")
plt.xlabel("Time (s)")
plt.ylabel("Neuron")
hide_input()
# Out:
#         <a id="1506678931" href="javascript:toggle_input_1506678931()"
#           >Show Input</a>
#
#         <script type="text/javascript">
#         var toggle_input_1506678931;
#         (function() {
#             if (typeof jQuery == 'undefined') {
#                 // no jQuery
#                 var link_1506678931 = document.getElementById("1506678931");
#                 var cell = link_1506678931;
#                 while (cell.className.split(' ')[0] != "cell"
#                        && cell.className.split(' ')[0] != "nboutput") {
#                     cell = cell.parentNode;
#                 }
#                 var input_1506678931;
#                 if (cell.className.split(' ')[0] == "cell") {
#                     for (var i = 0; i < cell.children.length; i++) {
#                         if (cell.children[i].className.split(' ')[0]
#                             == "input") {
#                             input_1506678931 = cell.children[i];
#                         }
#                     }
#                 } else {
#                     input_1506678931 = cell.previousElementSibling;
#                 }
#                 input_1506678931.style.display = "none"; // hide
#
#                 toggle_input_1506678931 = function() {
#                     if (input_1506678931.style.display == "none") {
#                         input_1506678931.style.display = ""; // show
#                         link_1506678931.innerHTML = "Hide Input";
#                     } else {
#                         input_1506678931.style.display = "none"; // hide
#                         link_1506678931.innerHTML = "Show Input";
#                     }
#                 }
#
#             } else {
#                 // jQuery
#                 var link_1506678931 = $("a[id='1506678931']");
#                 var cell_1506678931 = link_1506678931.parents("div.cell:first");
#                 if (cell_1506678931.length == 0) {
#                     cell_1506678931 = link_1506678931.parents(
#                         "div.nboutput:first");
#                 }
#                 var input_1506678931 = cell_1506678931.children("div.input");
#                 if (input_1506678931.length == 0) {
#                     input_1506678931 = cell_1506678931.prev("div.nbinput");
#                 }
#                 input_1506678931.hide();
#
#                 toggle_input_1506678931 = function() {
#                     if (input_1506678931.is(':hidden')) {
#                         input_1506678931.slideDown();
#                         link_1506678931[0].innerHTML = "Hide Input";
#                     } else {
#                         input_1506678931.slideUp();
#                         link_1506678931[0].innerHTML = "Show Input";
#                     }
#                 }
#             }
#         }());
#         </script>

# %% [markdown]
# ## Principle 3: Dynamics
#
# So far, we have been considering the values
# represented by ensembles as generic "signals."
# However, if we think of them instead
# as state variables in a dynamical system,
# then we can apply the methods of control theory
# or dynamic systems theory to brain models.
# Nengo automatically translates from standard dynamical systems descriptions
# to descriptions consistent with neural dynamics.
#
# In order to get interesting dynamics,
# we can connect populations recurrently (i.e., to themselves).
#
# Below is a simple harmonic oscillator
# implemented using this third principle.
# It needs is a bit of input to get it started.

# %%
model = nengo.Network(label="NEF summary")
with model:
    input = nengo.Node(lambda t: [1, 0] if t < 0.1 else [0, 0])
    oscillator = nengo.Ensemble(200, dimensions=2)
    nengo.Connection(input, oscillator)
    nengo.Connection(
        oscillator, oscillator, transform=[[1, 1], [-1, 1]], synapse=0.1)
    oscillator_probe = nengo.Probe(oscillator, synapse=0.02)

# %%
with nengo.Simulator(model) as sim:
    sim.run(3)

plt.figure(figsize=(10, 3.5))
plt.subplot(1, 2, 1)
plt.plot(sim.trange(), sim.data[oscillator_probe])
plt.ylim(-1.2, 1.2)
plt.xlabel('Time (s)')

plt.subplot(1, 2, 2)
plt.plot(sim.data[oscillator_probe][:, 0], sim.data[oscillator_probe][:, 1])
plt.grid()
plt.axis([-1.2, 1.2, -1.2, 1.2])
plt.xlabel('$x_1$')
plt.ylabel('$x_2$')
hide_input()
# Out:
#         <a id="551734587" href="javascript:toggle_input_551734587()"
#           >Show Input</a>
#
#         <script type="text/javascript">
#         var toggle_input_551734587;
#         (function() {
#             if (typeof jQuery == 'undefined') {
#                 // no jQuery
#                 var link_551734587 = document.getElementById("551734587");
#                 var cell = link_551734587;
#                 while (cell.className.split(' ')[0] != "cell"
#                        && cell.className.split(' ')[0] != "nboutput") {
#                     cell = cell.parentNode;
#                 }
#                 var input_551734587;
#                 if (cell.className.split(' ')[0] == "cell") {
#                     for (var i = 0; i < cell.children.length; i++) {
#                         if (cell.children[i].className.split(' ')[0]
#                             == "input") {
#                             input_551734587 = cell.children[i];
#                         }
#                     }
#                 } else {
#                     input_551734587 = cell.previousElementSibling;
#                 }
#                 input_551734587.style.display = "none"; // hide
#
#                 toggle_input_551734587 = function() {
#                     if (input_551734587.style.display == "none") {
#                         input_551734587.style.display = ""; // show
#                         link_551734587.innerHTML = "Hide Input";
#                     } else {
#                         input_551734587.style.display = "none"; // hide
#                         link_551734587.innerHTML = "Show Input";
#                     }
#                 }
#
#             } else {
#                 // jQuery
#                 var link_551734587 = $("a[id='551734587']");
#                 var cell_551734587 = link_551734587.parents("div.cell:first");
#                 if (cell_551734587.length == 0) {
#                     cell_551734587 = link_551734587.parents(
#                         "div.nboutput:first");
#                 }
#                 var input_551734587 = cell_551734587.children("div.input");
#                 if (input_551734587.length == 0) {
#                     input_551734587 = cell_551734587.prev("div.nbinput");
#                 }
#                 input_551734587.hide();
#
#                 toggle_input_551734587 = function() {
#                     if (input_551734587.is(':hidden')) {
#                         input_551734587.slideDown();
#                         link_551734587[0].innerHTML = "Hide Input";
#                     } else {
#                         input_551734587.slideUp();
#                         link_551734587[0].innerHTML = "Show Input";
#                     }
#                 }
#             }
#         }());
#         </script>
